# %%
marks=[22,49,98,80,3,0,99]
age=[18,12,22,23,45,67,70]

# %%
marks
# Out:
# [22, 49, 98, 80, 3, 0, 99]

# %%
age
# Out:
# [18, 12, 22, 23, 45, 67, 70]

# %%
#creating plot
import matplotlib.pyplot as plt
plt.plot(age,marks)
plt.show()

# %%
#scatter plot
plt.scatter(age,marks)
plt.show()
